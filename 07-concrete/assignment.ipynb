# %%
# ======================================================================================
# Notebook setup
# 
# Run this cell before all others to make sure that the Jupyter notebook works properly
# ======================================================================================

# Automatically reload all imported modules
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import os
import numpy as np

figsize = (20, 4.5)

# %% [markdown]
# # Concrete Compressive Strength
#
# This dataset is obtained from the [UCI repository](https://archive.ics.uci.edu/dataset/165/concrete+compressive+strength), where you can find additional information.
#
# The dataset contains information about sample of concrete, together with measurements of their compressive strength.
#
# Some examples of suggested activities:
#
# * Inspect the data (check distributions, correlations, patterns....)
# * Try to estimate the compressive strength based on the other attributes
# * Try to identify the most relevant attributes
# * Compare the performance of different models

# %%
fname = os.path.join('data', 'Concrete_Data.csv')
data = pd.read_csv(fname)
display(data)
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Concrete compressive strength
# 0               1040.0           676.0   28                          79.99
# ...
